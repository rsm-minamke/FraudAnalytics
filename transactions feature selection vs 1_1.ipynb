# %% [markdown]
# This feature selection notebook does a filter followed by a wrapper for a binary dependent variable (binary classification). It's capable of doing the filter on more than one file. The variable files are called vars1.csv, vars2.csv ... Or you can make the input file name(s) anything you want. The filter runs separately on each vars file and keeps the top num_filter variables from each file. If there are more than one vars files we'll again select the top num_filter variables across all the vars.csv files.
#
# Things to modify if you use this notebook:
#
# To keep things simple arrange your data so that the rare class has the label 1 and the
# common class has the label 0. You can do the reverse if you want but then you need to modify more things in this code.
#
# The most important parameters are in cell 2 and 20. The main ones you should try experimenting with are num_out_of_filter and num_out_of_wrapper. In cell 2 you should set the name of the record identifying number (it's good to use a record number to keep track of things) and the name of the binary dependent variable. This particular version is set for a fraud problem.
#
# Make sure your validation/out-of-time population and any other record exclusion is set correctly and as you want for your problem in cell 3. This define the records in the data file that you for whatever reason you don't want to include in your feature selection process.
#
# Cell 20 has the SequentialFeatureSelector (SFS) settings. You can try different wrapper models with different amounts of commplexity. You can select either forward or backward. The filter is pretty fast. The wrapper is what takes the most time. I find forward selection runs much faster than backward.
#
# There's a parameter njobs that controls the # threads used in the wrapper. Set it to 1 for a single thread and it should work fine, but you might be able to succeed with njobs = -1, which lets the machine set the maximum # threads based on the CPU. With this setting the kernel may die because of memory. The njobs = -1 doesn't take into consideration the memory requirements.
#
# Recommendations: Try a few simple runs just to make sure all's working. Start with num_out_of_filter = 20, num_out_of_wrapper = 5, increase from there. I like num_out_of_filter as high as around 10% to 20% of the # candidate variables, but not much higher than a few hundred. You don't need num_out_of_wrapper large if you're doing forward selection. Most problems will saturate before 20. You can try a few different simple wrapper models like RF (5 trees, 10 layers), catboost (10 trees, 3 layers), LGBM (same). They're pretty fast. You can try forward and backward. I'd start with forward. In the end, select one of these as your favorite run and go with those variables. Don't mix variables across different runs.
#
# If balance = 0 the entire files are used. If balance != 0 then balance is the RATIO OF BADS TO GOODS retained for the rest of the feature selection. We keep all the rare class (bads) and downsample the goods. I think in general it's better to keep balance = 0.

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.14.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (3.9.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\mrun7\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\mrun7\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import datetime as dt
import gc
from sklearn.ensemble import RandomForestClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
# %matplotlib inline
start_time = dt.datetime.now()

# %%
# set some parameters
num_files = 1 # this is the number of files for the candidate variables, usually just 1.
# num_out_of_filter is the number of variables that we'll keep from the filter. The more the better, but the wrapper will run slower.
# num_out_of_wrapper is the number we'll keep from the wrapper. These will then be our final variables for the models.
# I recommend set num_out_of_filter to be about 10 to 20% of the original # variables.
num_out_of_filter = 250
# I recommend set num_out_of_wrapper to be about 40, then look for a saturation of the model performance as variables are added.
# Then you can run it again with num_out_of_wrapper just a bit above this saturation point, not more than about twice this saturation number.
num_out_of_wrapper = 40
balance = 0
detect_rate = .03
index_name = 'Recnum'
y_name = 'Fraud'
good_label = 0
bad_label = 1

# %% [markdown]
# ## Run a filter on all the files

# %%
# %%time
filter_score_df_list = []
for i in range(num_files):
#     file_name = "vars"+str(i+1)+'.csv'
    file_name = r"C:\Users\mrun7\Downloads\candidate_variables\candidate_variables.csv"
    df = pd.read_csv(file_name)
    print("********** working on",file_name,"size is",df.shape)
    df = df.set_index(index_name) 
    df = df[df.index <= 85730] # remove the last two months as the out-of-time data (OOT)
    df = df[df.index >= 3515] # remove the first 2 weeks of records since their variables aren't well formed
    df['RANDOM'] = np.random.ranf(len(df)) # add a random number variable to make sure it doesn't come up as important
    goods = df[df[y_name] == good_label]
    bads = df[df[y_name] == bad_label]
    del df # don't need this file anymore
    num_goods = len(goods)
    num_bads = len(bads)
    num_vars = len(bads.columns)-2
    if(balance != 0):
        if(i == 0):
            num_goods_desired = int(min(num_goods,num_bads*balance))
            goods = goods.sample(n=num_goods_desired,random_state=1)
            goods_keep = list(goods.index)
            goods_keep.sort()
    
        if(i > 0):
            goods = goods.loc[goods_keep] 
            
    df_sampled = pd.concat([goods,bads])
    df_sampled.sort_index(inplace=True)
    filter_score = pd.DataFrame(np.zeros((num_vars+1,2)))
    filter_score.columns = ['variable','filter score']   
    j = 0
    for column in df_sampled:
        filter_score.loc[j,'variable'] = column
        filter_score.loc[j,'filter score'] = sps.ks_2samp(goods[column],bads[column])[0]
        j = j+1
        if j%100 == 0:
            print(j)

    filter_score.sort_values(by=['filter score'], ascending=False, inplace=True)
    vars_keep = list(filter_score['variable'][1:num_out_of_filter+1]) 
    print(file_name,filter_score.head(20))
    if(i == 0): # if first time through need to initialize some stuff
        Y = pd.DataFrame(df_sampled[y_name], index=df_sampled.index)
        df_top = df_sampled.filter(vars_keep, axis=1)
            
    if(i > 0): # if more than one variable file we use this loop
        data_new_top = df_sampled.filter(vars_keep, axis=1)
        df_top = pd.concat([df_top,data_new_top], axis=1)

    filter_score_df_list.append(filter_score)
    
    del goods # delete these before starting the next file, if any
    del bads
    gc.collect()
filter_score = pd.concat(filter_score_df_list)
# Out:
# ********** working on C:\Users\mrun7\Downloads\candidate_variables\candidate_variables.csv size is (98037, 2651)
# <timed exec>:33: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Amount' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# C:\Users\mrun7\Downloads\candidate_variables\candidate_variables.csv                                    variable  filter score
# 1                                     Fraud      1.000000
# 21                          Cardnum_total_1      0.591114
# 17                          Cardnum_count_1      0.576927
# 26                          Cardnum_count_3      0.572199
# 30                          Cardnum_total_3      0.569585
# 12                          Cardnum_total_0      0.555080
# 8                           Cardnum_count_0      0.529072
# 1580                  Cardnum_vdratio_1by60      0.519909
# 2089  Cardnum_unique_count_for_card_state_1      0.518606
# 2083    Cardnum_unique_count_for_card_zip_1      0.517208
# 1579                  Cardnum_vdratio_1by30      0.516476
# 35                          Cardnum_count_7      0.516399
# 39                          Cardnum_total_7      0.515987
# 2077    Cardnum_unique_count_for_Merchnum_1      0.513278
# 588                        Card_dow_total_7      0.508754
# 1648                 Card_dow_vdratio_0by60      0.508448
# 2090  Cardnum_unique_count_for_card_state_3      0.508357
# 1647                 Card_dow_vdratio_0by30      0.507694
# 2084    Cardnum_unique_count_for_card_zip_3      0.506867
# 19                            Cardnum_max_1      0.504805
# CPU times: total: 1min
# Wall time: 1min 3s

# %%
filter_score.sort_values(by=['filter score'], ascending=False, inplace=True)
filter_score.reset_index(drop=True,inplace=True)

# %%
filter_score.head(30)
# Out:
#                                    variable  filter score
# 0                                     Fraud      1.000000
# 1                           Cardnum_total_1      0.591114
# 2                           Cardnum_count_1      0.576927
# 3                           Cardnum_count_3      0.572199
# 4                           Cardnum_total_3      0.569585
# 5                           Cardnum_total_0      0.555080
# 6                           Cardnum_count_0      0.529072
# 7                     Cardnum_vdratio_1by60      0.519909
# 8     Cardnum_unique_count_for_card_state_1      0.518606
# 9       Cardnum_unique_count_for_card_zip_1      0.517208
# 10                    Cardnum_vdratio_1by30      0.516476
# 11                          Cardnum_count_7      0.516399
# 12                          Cardnum_total_7      0.515987
# 13      Cardnum_unique_count_for_Merchnum_1      0.513278
# 14                         Card_dow_total_7      0.508754
# 15                   Card_dow_vdratio_0by60      0.508448
# 16    Cardnum_unique_count_for_card_state_3      0.508357
# 17                   Card_dow_vdratio_0by30      0.507694
# 18      Cardnum_unique_count_for_card_zip_3      0.506867
# 19                            Cardnum_max_1      0.504805
# 20      Cardnum_unique_count_for_Merchnum_3      0.503768
# 21                   Card_dow_vdratio_0by14      0.502657
# 22                    Cardnum_vdratio_1by14      0.497396
# 23                Cardnum_variability_max_0      0.496485
# 24                Cardnum_variability_max_1      0.493475
# 25                            Cardnum_max_0      0.492316
# 26  Card_dow_unique_count_for_merch_state_1      0.490938
# 27    Card_dow_unique_count_for_merch_zip_1      0.490737
# 28                    Card_dow_vdratio_0by7      0.490636
# 29                    Cardnum_actual/toal_0      0.489477

# %%
filter_score.tail(10)
# Out:
#                                                variable  filter score
# 2641   Merchdesc_Zip_unique_count_for_Merchdesc_State_7      0.000038
# 2642  Merchdesc_Zip_unique_count_for_Merchdesc_State_14      0.000038
# 2643          merch_zip_unique_count_for_merch_state_14      0.000025
# 2644  Merchnum_desc_Zip_unique_count_for_Merchnum_de...      0.000013
# 2645           merch_zip_unique_count_for_merch_state_7      0.000013
# 2646  Card_Merchdesc_Zip_unique_count_for_Merchdesc_...      0.000013
# 2647           merch_zip_unique_count_for_merch_state_3      0.000000
# 2648                           Merchant_dominance_score      0.000000
# 2649           merch_zip_unique_count_for_merch_state_1      0.000000
# 2650              card_merch_unique_count_for_Cardnum_1      0.000000

# %%
filter_score.shape
# Out:
# (2651, 2)

# %%
filter_score.head(80).to_csv('filter_top.csv')
vars_keep = list(filter_score['variable'][num_files:num_out_of_filter+3])
print(i,' vars_keep:',vars_keep)
# Out:
# 0  vars_keep: ['Cardnum_total_1', 'Cardnum_count_1', 'Cardnum_count_3', 'Cardnum_total_3', 'Cardnum_total_0', 'Cardnum_count_0', 'Cardnum_vdratio_1by60', 'Cardnum_unique_count_for_card_state_1', 'Cardnum_unique_count_for_card_zip_1', 'Cardnum_vdratio_1by30', 'Cardnum_count_7', 'Cardnum_total_7', 'Cardnum_unique_count_for_Merchnum_1', 'Card_dow_total_7', 'Card_dow_vdratio_0by60', 'Cardnum_unique_count_for_card_state_3', 'Card_dow_vdratio_0by30', 'Cardnum_unique_count_for_card_zip_3', 'Cardnum_max_1', 'Cardnum_unique_count_for_Merchnum_3', 'Card_dow_vdratio_0by14', 'Cardnum_vdratio_1by14', 'Cardnum_variability_max_0', 'Cardnum_variability_max_1', 'Cardnum_max_0', 'Card_dow_unique_count_for_merch_state_1', 'Card_dow_unique_count_for_merch_zip_1', 'Card_dow_vdratio_0by7', 'Cardnum_actual/toal_0', 'Card_dow_unique_count_for_Card_Merchdesc_1', 'Card_dow_unique_count_for_state_des_1', 'Card_dow_count_7', 'Cardnum_vdratio_1by7', 'Cardnum_unique_count_for_card_state_7', 'Cardnum_actual/toal_1', 'Card_dow_total_14', 'Cardnum_unique_count_for_card_zip_7', 'Cardnum_unique_count_for_Merchnum_7', 'Cardnum_max_3', 'Cardnum_actual/max_0', 'Cardnum_total_amount_1_by_60', 'Cardnum_day_since', 'Card_dow_day_since', 'Card_dow_max_7', 'Cardnum_total_14', 'Cardnum_vdratio_0by60', 'Card_dow_unique_count_for_merch_zip_7', 'Card_dow_unique_count_for_merch_state_7', 'Cardnum_unique_count_for_card_state_14', 'Cardnum_count_1_by_60', 'Cardnum_count_1_by_60_sq', 'Cardnum_unique_count_for_card_zip_14', 'Cardnum_count_1_by_30_sq', 'Cardnum_count_1_by_30', 'Cardnum_actual/max_1', 'Cardnum_unique_count_for_Merchnum_14', 'Card_dow_max_14', 'Card_dow_count_14', 'Cardnum_count_14', 'Cardnum_vdratio_0by30', 'Card_dow_total_30', 'Card_dow_unique_count_for_state_des_7', 'Card_dow_unique_count_for_Card_Merchdesc_7', 'Card_dow_unique_count_for_merch_state_14', 'Card_dow_unique_count_for_merch_zip_14', 'Cardnum_variability_max_3', 'Cardnum_actual/toal_3', 'Cardnum_total_amount_1_by_30', 'Cardnum_count_1_by_14_sq', 'Cardnum_count_1_by_14', 'Card_dow_variability_max_7', 'Cardnum_vdratio_0by14', 'Card_dow_actual/toal_7', 'Card_dow_unique_count_for_Card_Merchdesc_14', 'Card_dow_unique_count_for_state_des_14', 'Card_dow_max_30', 'Cardnum_unique_count_for_card_state_30', 'Card_dow_total_60', 'Cardnum_max_7', 'Card_dow_unique_count_for_merch_state_30', 'Card_dow_unique_count_for_merch_zip_30', 'Card_dow_count_30', 'Card_dow_count_0_by_60', 'Card_dow_count_0_by_60_sq', 'Cardnum_total_amount_0_by_60', 'Cardnum_vdratio_0by7', 'Cardnum_unique_count_for_card_zip_30', 'Cardnum_total_30', 'Cardnum_unique_count_for_Merchnum_30', 'Card_dow_actual/max_7', 'Card_dow_variability_max_14', 'Cardnum_total_amount_1_by_14', 'card_state_total_amount_1_by_60', 'Cardnum_actual/max_3', 'card_zip_total_amount_1_by_60', 'Cardnum_variability_avg_0', 'card_state_count_1_by_60_sq', 'card_state_count_1_by_60', 'Card_dow_max_60', 'Card_dow_count_0_by_30', 'Card_dow_count_0_by_30_sq', 'card_zip_count_1_by_60', 'card_zip_count_1_by_60_sq', 'Card_dow_unique_count_for_state_des_30', 'Card_dow_unique_count_for_Card_Merchdesc_30', 'Cardnum_avg_0', 'Card_dow_actual/toal_14', 'Cardnum_total_amount_0_by_30', 'Cardnum_count_0_by_60_sq', 'Cardnum_count_0_by_60', 'Cardnum_avg_1', 'Cardnum_unique_count_for_card_state_60', 'Card_dow_total_amount_0_by_60', 'Cardnum_count_30', 'Card_dow_unique_count_for_merch_state_60', 'Card_dow_unique_count_for_merch_zip_60', 'Cardnum_count_1_by_7_sq', 'Cardnum_count_1_by_7', 'Cardnum_actual/avg_0', 'Cardnum_variability_max_7', 'Cardnum_count_0_by_30_sq', 'Cardnum_count_0_by_30', 'Cardnum_actual/toal_7', 'Card_Merchnum_Zip_total_amount_1_by_60', 'card_merch_total_amount_1_by_60', 'Card_Merchnum_State_total_amount_1_by_60', 'card_state_count_1_by_30_sq', 'card_state_count_1_by_30', 'card_merch_count_1_by_60', 'card_merch_count_1_by_60_sq', 'Card_Merchnum_State_count_1_by_60', 'Card_Merchnum_State_count_1_by_60_sq', 'Card_Merchnum_Zip_count_1_by_60_sq', 'Card_Merchnum_Zip_count_1_by_6 ...

# %%
vars_keep_df = pd.DataFrame({'col':vars_keep})
vars_keep_df.to_csv('vars_keep_filter.csv',index=False)
df_keep = df_top.filter(vars_keep, axis=1)
df_keep.head()
# Out:
#         Cardnum_total_1  Cardnum_count_1  Cardnum_count_3  Cardnum_total_3  \
# Recnum
# 3515            1551.02              3.0              7.0          1964.73
# 3516             660.87              2.0             34.0           834.91
# 3517            2904.08              7.0             14.0          8459.94
# 3518             664.49              3.0             35.0           838.53
# 3519              16.28              1.0              1.0            16.28
#
#         Cardnum_total_0  Cardnum_count_0  Cardnum_vdratio_1by60  \
# Recnum
# 3515             333.47              1.0               0.000641
# 3516               4.37              1.0               0.000140
# 3517             271.93              1.0               0.001768
# 3518               7.99              2.0               0.000417
# 3519              16.28              1.0               0.000011
#
#         Cardnum_unique_count_for_card_state_1  \
# Recnum
# 3515                                      3.0
# 3516                                      2.0
# 3517                                      4.0
# 3518                                      2.0
# 3519                                      1.0
#
#         Cardnum_unique_count_for_card_zip_1  Cardnum_vdratio_1by30  ...  \
# Recnum                                                              ...
# 3515                                    3.0               0.001282  ...
# 3516                                    2.0               0.000280  ...
# 3517                                    5.0               0.003535  ...
# 3518                                    2.0               0.000833  ...
# 3519                                    1.0               0.000023  ...
#
#         card_zip_total_amount_0_by_60  Card_Merchnum_State_total_14  \
# Recnum
# 3515                         0.002835                       1960.27
# 3516                         0.000137                        499.22
# 3517                         0.001965                       2306.98
# 3518                         0.000250                        502.84
# 3519                         0.016667                         16.28
#
#         card_merch_total_14  Card_Merchnum_Zip_total_14  Cardnum_avg_7  \
# Recnum
# 3515                1960.27                     1960.27     330.139091
# 3516                 499.22                      499.22      13.857361
# 3517                2306.98                     2306.98     569.067059
# 3518                 502.84                      502.84      13.717123
# 3519                  16.28                       16.28      16.280000
#
#         card_zip_count_0_by_60  card_zip_count_0_by_60_sq  \
# Recnum
# 3515                  0.005556                   0.000093
# 3516                  0.000141                   0.000002
# 3517                  0.001852                   0.000031
# 3518                  0.000280                   0.000005
# 3519                  0.016667                   0.000278
#
#         card_state_total_14  card_zip_total_7  card_state_vdratio_1by14
# Recnum
# 3515                1960.27           1960.27                  0.004762
# 3516                 530.02            341.23                  0.000202
# 3517                2679.04            582.94                  0.010714
# 3518                 533.64            344.85                  0.001200
# 3519                  16.28             16.28                  0.000048
#
# [5 rows x 250 columns]

# %%
df_keep.shape
# Out:
# (81893, 250)

# %%
Y.head()
# Out:
#         Fraud
# Recnum
# 3515      0.0
# 3516      0.0
# 3517      0.0
# 3518      0.0
# 3519      0.0

# %%
Y = Y.values.ravel()
Y_save = Y.copy()

# %%
# Y = np.array(Y)
X = df_keep
print(Y)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
print('time to here:', dt.datetime.now() - start_time)
# Out:
# time to here: 0:01:03.527879

# %%
print(X.shape,Y.shape)
# Out:
# (81893, 250) (81893,)

# %%
print(type(X),type(Y))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'numpy.ndarray'>

# %%
# I'd like to define a scoring for the wrapper that's KS, but I haven't gotten around to this yet.
# def KSscore(classifier, x,y)

# %%
def fdr(classifier, x, y, cutoff=0.03):
    # Calculates FDR score for the given classifier on dataset x and y with cutoff value
    return fdr_prob(y, classifier.predict_proba(x), cutoff)

def fdr_prob(y, y_prob, cutoff=0.03):
    if len(y_prob.shape) > 1:  # Check if y_prob is multi-dimensional
        y_prob = y_prob[:, -1]  # Use the last column if it's for the positive class
    y_prob = y_prob.flatten()  # Ensure y_prob is 1D
    num_fraud = np.sum(y == 1)  # Count the total number of frauds

    # Sort the proba list from high to low while retaining the true (not predicted) fraud label
    sorted_prob = np.array(sorted(zip(y_prob, y), key=lambda x: x[0], reverse=True))
    cutoff_index = int(len(y) * cutoff)  # Calculate index for cutoff
    cutoff_bin = sorted_prob[:cutoff_index, 1]  # Get labels up to the cutoff

    # Return the FDR score (#fraud_in_cutoff / #total_fraud)
    return np.sum(cutoff_bin == 1) / num_fraud if num_fraud > 0 else 0

# %% [markdown]
# ## Run a wrapper on the remaining top variables

# %%
# This is a parallel running parameter. You can try it set to -1, but sometimes the data is too large to
# be divided into that many threads and the next cell quits. A safe value is 1 for no parallelization but it 
# the runs slower. You might experiment to see how big you can set this for your data on your machine.
njobs = -1

# %%
# %%time
import warnings 
warnings.filterwarnings("ignore") 
# Keep the classifier settings simple. You don't need really good models, only good 
# enough to evaluate which variables help and in which order and combinations.

# If you're doing forward selection it's enough to stop at num_out_of_wrapper variables. 
# If you're doing backward selection you need to go through all the variables to get a sorted list of num_out_of_wrapper variables.

nfeatures = len(X.columns)
# clf = RandomForestClassifier(n_estimators=5) # simple, fast nonlinear model for the wrapper
clf = LGBMClassifier(n_estimators=20,num_leaves=4) # simple, fast nonlinear model for the wrapper
# clf = CatBoostClassifier(verbose=0,iterations=20,depth=3)
sfs = SFS(clf,k_features=num_out_of_wrapper,forward=True,verbose=0,scoring=fdr,cv=2,n_jobs=njobs) # use for forward selection
# sfs = SFS(clf,k_features=1,forward=False,verbose=0,scoring=fdr,cv=2,n_jobs=njobs) # use for backward selection
sfs.fit(X,Y)
# Out:
# CPU times: total: 1min 21s
# Wall time: 4h 26min 41s
# SequentialFeatureSelector(cv=2,
#                           estimator=LGBMClassifier(n_estimators=20,
#                                                    num_leaves=4),
#                           k_features=(40, 40), n_jobs=-1,
#                           scoring=<function fdr at 0x0000022369D56AC0>)

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
fig1 = plot_sfs(sfs.get_metric_dict(),kind='std_dev', figsize=(10, 6))
plt.xticks(np.arange(0, num_out_of_wrapper, step=1))
plt.yticks(np.arange(0,1,step=.02))
plt.ylim([.5,.8])
plt.xlim(0,num_out_of_wrapper)
plt.title('Stepwise Selection')
plt.grid()
plt.savefig('performance_nvars.png')
plt.show()

# %%
vars_FS = pd.DataFrame.from_dict(sfs.get_metric_dict()).T

# %%
ordered_vars_FS = vars_FS.copy()
for i in range(len(ordered_vars_FS)):
    ordered_vars_FS.loc[i+1,'add variables in this order'] = int(i+1)
    if i+1 == 1:
        ordered_vars_FS.loc[i+1,'variable name'] = (list(ordered_vars_FS.loc[i+1,'feature_names'])[0])
    else:
        ordered_vars_FS.loc[i+1,'variable name'] = (list(set(ordered_vars_FS.loc[i+1,'feature_names']) - set(ordered_vars_FS.loc[i,'feature_names'])))[0]
# You might also need this following line. It converts a list to a string
#         ordered_vars_FS.loc[i+1,'variable name'] = ordered_vars_FS.loc[i+1,'variable name'][0]

# %%
ordered_vars_FS
# Out:
#                                           feature_idx  \
# 1                                                (7,)
# 2                                            (7, 239)
# 3                                        (7, 92, 239)
# 4                                    (7, 29, 92, 239)
# 5                               (7, 29, 92, 134, 239)
# 6                          (7, 29, 92, 101, 134, 239)
# 7                     (7, 29, 92, 101, 120, 134, 239)
# 8                (7, 29, 92, 101, 120, 134, 232, 239)
# 9            (7, 29, 30, 92, 101, 120, 134, 232, 239)
# 10       (7, 29, 30, 61, 92, 101, 120, 134, 232, 239)
# 11   (7, 29, 30, 61, 62, 92, 101, 120, 134, 232, 239)
# 12  (7, 29, 30, 61, 62, 73, 92, 101, 120, 134, 232...
# 13  (7, 29, 30, 61, 62, 73, 74, 92, 101, 120, 134,...
# 14  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 120,...
# 15  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 16  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 17  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 18  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 19  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 20  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 21  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 22  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 23  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 105,...
# 24  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 103,...
# 25  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 103,...
# 26  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 103,...
# 27  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 103,...
# 28  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 103,...
# 29  (7, 29, 30, 61, 62, 73, 74, 92, 101, 102, 103,...
# 30  (7, 29, 30, 61, 62, 73, 74, 85, 92, 101, 102, ...
# 31  (7, 29, 30, 43, 61, 62, 73, 74, 85, 92, 101, 1...
# 32  (7, 29, 30, 43, 61, 62, 73, 74, 85, 92, 94, 10...
# 33  (7, 29, 30, 43, 61, 62, 73, 74, 85, 92, 94, 10...
# 34  (7, 29, 30, 43, 61, 62, 73, 74, 81, 85, 92, 94...
# 35  (7, 29, 30, 43, 61, 62, 73, 74, 81, 85, 90, 92...
# 36  (7, 29, 30, 43, 46, 61, 62, 73, 74, 81, 85, 90...
# 37  (7, 29, 30, 43, 46, 47, 61, 62, 73, 74, 81, 85...
# 38  (7, 29, 30, 43, 46, 47, 60, 61, 62, 73, 74, 81...
# 39  (7, 29, 30, 43, 46, 47, 60, 61, 62, 63, 73, 74...
# 40  (7, 29, 30, 43, 46, 47, 60, 61, 62, 63, 64, 73...
#
#                                    cv_scores avg_score  \
# 1   [0.5030364372469636, 0.5065856129685917]  0.504811
# 2   [0.6336032388663968, 0.6362715298885512]  0.634937
# 3   [0.6629554655870445, 0.6534954407294833]  0.658225
# 4   [0.6700404858299596, 0.6595744680851063]  0.664807
# 5   [0.6710526315789473, 0.6676798378926039]  0.669366
# 6   [0.6619433198380567, 0.6788247213779128]  0.670384
# 7   [0.6781376518218624, 0.6818642350557245]  0.680001
# 8    [0.6781376518218624, 0.690982776089159]   0.68456
# 9    [0.6781376518218624, 0.690982776089159]   0.68456
# 10   [0.6781376518218624, 0.690982776089159]   0.68456
# 11   [0.6781376518218624, 0.690982776089159]   0.68456
# 12   [0.6781376518218624, 0.690982776089159]   0.68456
# 13   [0.6781376518218624, 0.690982776089159]   0.68456
# 14   [0.6781376518218624, 0.690982776089159]   0.68456
# 15   [0.6781376518218624, 0.690982776089159]   0.68456
# 16   [0.6781376518218624, 0.690982776089159]   0.68456
# 17   [0.6781376518218624, 0.690982776089159]   0.68456
# 18   [0.6781376518218624, 0.690982776089159]   0.68456
# 19   [0.6781376518218624, 0.690982776089159]   0.68456
# 20   [0.6781376518218624, 0.690982776089159]   0.68456
# 21   [0.6781376518218624, 0.690982776089159]   0.68456
# 22   [0.6781376518218624, 0.690982776089159]   0.68456
# 23   [0.6781376518218624, 0.690982776089159]   0.68456
# 24   [0.6781376518218624, 0.690982776089159]   0.68456
# 25   [0.6781376518218624, 0.690982776089159]   0.68456
# 26   [0.6781376518218624, 0.690982776089159]   0.68456
# 27   [0.6781376518218624, 0.690982776089159]   0.68456
# 28  [0.6781376518218624, 0.6899696048632219]  0.684054
# 29  [0.6781376518218624, 0.6899696048632219]  0.684054
# 30  [0.6781376518218624, 0.6889564336372846]  0.683547
# 31  [0.6781376518218624, 0.6879432624113475]   0.68304
# 32  [0.6791497975708503, 0.6919959473150963]  0.685573
# 33  [0.6740890688259109, 0.7011144883485309]  0.687602
# 34  [0.6771255060728745, 0.7011144883485309]   0.68912
# 35  [0.6811740890688259, 0.6990881458966566]  0.690131
# 36  [0.6811740890688259, 0.6990881458966566]  0.690131
# 37  [0.6811740890688259, 0.6990881458966566]  0.690131
# 38  [0.6811740890688259, 0.6990881458966566]  0.690131
# 39  [0.6811740890688259, 0.6990881458966566]  0.690131
# 40  [0.6811740890688259, 0.6990881458966566]  0.690131
#
#                                         feature_names  ci_bound   std_dev  \
# 1            (Cardnum_unique_count_for_card_state_1,)  0.007635  0.001775
# 2   (Cardnum_unique_count_for_card_state_1, Card_M...   0.00574  0.001334
# 3   (Cardnum_unique_count_for_card_state_1, card_s...  0.020352   0.00473
# 4   (Cardnum_unique_count_for_card_state_1, Card_d...  0.022516  0.005233
# 5   (Cardnum_unique_count_for_card_state_1, Card_d...  0.007256  0.001686
# 6   (Cardnum_unique_count_for_card_state_1, Card_d...  0.036317  0.008441
# 7   (Cardnum_unique_count_for_card_state_1, Card_d...  0.008017  0.001863
# 8   (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 9   (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 10  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 11  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 12  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 13  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 14  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 15  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 16  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 17  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 18  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 19  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 20  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 21  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 22  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 23  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 24  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 25  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 26  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 27  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027634  0.006423
# 28  (Cardnum_unique_count_for_card_state_1, Card_d...  0.025454  0.005916
# 29  (Cardnum_unique_count_for_card_state_1, Card_d...  0.025454  0.005916
# 30  (Cardnum_unique_count_for_card_state_1, Card_d...  0.023275  0.005409
# 31  (Cardnum_unique_count_for_card_state_1, Card_d...  0.021095  0.004903
# 32  (Cardnum_unique_count_for_card_state_1, Card_d...  0.027636  0.006423
# 33  (Cardnum_unique_count_for_card_state_1, Card_d...   0.05814  0.013513
# 34  (Cardnum_unique_count_for_card_state_1, Card_d...  0.051608  0.011994
# 35  (Cardnum_unique_count_for_card_state_1, Card_d...  0.038539  0.008957
# 36  (Cardnum_unique_count_for_card_state_1, Card_d...  0.038539  0.008957
# 37  (Cardnum_unique_count_for_card_state_1, Card_d...  0.038539  0.008957
# 38  (Cardnum_unique_count_for_card_state_1, Card_d...  0.038539  0.008957
# 39  (Cardnum_unique_count_for_card_state_1, Card_d...  0.038539  0.008957
# 40  (Cardnum_unique_count_for_card_state_1, Card_d...  0.038539  0.008957
#
#      std_err  add variables in this order  \
# 1   0.001775                          1.0
# 2   0.001334                          2.0
# 3    0.00473                          3.0
# 4   0.005233                          4.0
# 5   0.001686                          5.0
# 6   0.008441                          6.0
# 7   0.001863                          7.0
# 8   0.006423                          8.0
# 9   0.006423                          9.0
# 10  0.006423                         10.0
# 11  0.006423                         11.0
# 12  0.006423                         12.0
# 13  0.006423                         13.0
# 14  0.006423                         14.0
# 15  0.006423                         15.0
# 16  0.006423                         16.0
# 17  0.006423                         17.0
# 18  0.006423                         18.0
# 19  0.006423                         19.0
# 20  0.006423                         20.0
# 21  0.006423                         21.0
# 22  0.006423                         22.0
# 23  0.006423                         23.0
# 24  0.006423                         24.0
# 25  0.006423                         25.0
# 26  0.006423                         26.0
# 27  0.006423                         27.0
# 28  0.005916                         28.0
# 29  0.005916                         29.0
# 30  0.005409                         30.0
# 31  0.004903                         31.0
# 32  0.006423                         32.0
# 33  0.013513                         33.0
# 34  0.011994                         34.0
# 35  0.008957                         35.0
# 36  0.008957                         36.0
# 37  0.008957                         37.0
# 38  0.008957                         38.0
# 39  0.008957                         39.0
# 40  0.008957                         40.0
#
#                                   variable name
# 1         Cardnum_unique_count_for_card_state_1
# 2                   Card_Merchnum_desc_total_14
# 3               card_state_total_amount_1_by_60
# 4    Card_dow_unique_count_for_Card_Merchdesc_1
# 5                                 Cardnum_avg_3
# 6                        card_zip_count_1_by_60
# 7                      Cardnum_count_0_by_30_sq
# 8                              card_state_max_3
# 9         Card_dow_unique_count_for_state_des_1
# 10        Card_dow_unique_count_for_state_des_7
# 11   Card_dow_unique_count_for_Card_Merchdesc_7
# 12  Card_dow_unique_count_for_Card_Merchdesc_14
# 13       Card_dow_unique_count_for_state_des_14
# 14                    card_zip_count_1_by_60_sq
# 15                                Cardnum_avg_0
# 16                        Cardnum_count_0_by_30
# 17                  card_state_count_1_by_30_sq
# 18                     card_state_count_1_by_30
# 19                               Card_dow_avg_7
# 20                  Card_dow_variability_max_30
# 21                              Card_dow_avg_14
# 22                              Card_dow_avg_30
# 23  Card_dow_unique_count_for_Card_Merchdesc_60
# 24       Card_dow_unique_count_for_state_des_30
# 25  Card_dow_unique_count_for_Card_Merchdesc_30
# 26       Card_dow_unique_count_for_state_des_60
# 27                             card_state_max_1
# 28           Card_Merchnum_Zip_count_1_by_60_sq
# 29              Card_Merchnum_Zip_count_1_by_60
# 30                         Cardnum_vdratio_0by7
# 31                               Card_dow_max_7
# 32                card_zip_total_amount_1_by_60
# 33                             Cardnum_total_60
# 34                            Card_dow_count_30
# 35                  Card_dow_variability_max_14
# 36        Card_dow_unique_count_for_merch_zip_7
# 37      Card_dow_unique_count_for_merch_state_7
# 38                            Card_dow_total_30
# 39     Card_dow_unique_count_for_merch_state_14
# 40       Card_dow_unique_count_for_merch_zip_14

# %%
ordered_vars_FS.to_csv('Wrapper_selection_info.csv', index=False)

# %%
vars_keep = ordered_vars_FS['variable name']
vars_keep_list = ordered_vars_FS['variable name'].tolist()
vars_keep.to_csv('final_vars_list.csv',index=False)
vars_keep
# Out:
# 1           Cardnum_unique_count_for_card_state_1
# 2                     Card_Merchnum_desc_total_14
# 3                 card_state_total_amount_1_by_60
# 4      Card_dow_unique_count_for_Card_Merchdesc_1
# 5                                   Cardnum_avg_3
# 6                          card_zip_count_1_by_60
# 7                        Cardnum_count_0_by_30_sq
# 8                                card_state_max_3
# 9           Card_dow_unique_count_for_state_des_1
# 10          Card_dow_unique_count_for_state_des_7
# 11     Card_dow_unique_count_for_Card_Merchdesc_7
# 12    Card_dow_unique_count_for_Card_Merchdesc_14
# 13         Card_dow_unique_count_for_state_des_14
# 14                      card_zip_count_1_by_60_sq
# 15                                  Cardnum_avg_0
# 16                          Cardnum_count_0_by_30
# 17                    card_state_count_1_by_30_sq
# 18                       card_state_count_1_by_30
# 19                                 Card_dow_avg_7
# 20                    Card_dow_variability_max_30
# 21                                Card_dow_avg_14
# 22                                Card_dow_avg_30
# 23    Card_dow_unique_count_for_Card_Merchdesc_60
# 24         Card_dow_unique_count_for_state_des_30
# 25    Card_dow_unique_count_for_Card_Merchdesc_30
# 26         Card_dow_unique_count_for_state_des_60
# 27                               card_state_max_1
# 28             Card_Merchnum_Zip_count_1_by_60_sq
# 29                Card_Merchnum_Zip_count_1_by_60
# 30                           Cardnum_vdratio_0by7
# 31                                 Card_dow_max_7
# 32                  card_zip_total_amount_1_by_60
# 33                               Cardnum_total_60
# 34                              Card_dow_count_30
# 35                    Card_dow_variability_max_14
# 36          Card_dow_unique_count_for_merch_zip_7
# 37        Card_dow_unique_count_for_merch_state_7
# 38                              Card_dow_total_30
# 39       Card_dow_unique_count_for_merch_state_14
# 40         Card_dow_unique_count_for_merch_zip_14
# Name: variable name, dtype: object

# %%
filter_score.set_index('variable',drop=True,inplace=True)
filter_score = filter_score.iloc[1:,:]
filter_score
# Out:
#                                                     filter score
# variable
# Cardnum_total_1                                         0.591114
# Cardnum_count_1                                         0.576927
# Cardnum_count_3                                         0.572199
# Cardnum_total_3                                         0.569585
# Cardnum_total_0                                         0.555080
# ...                                                          ...
# Card_Merchdesc_Zip_unique_count_for_Merchdesc_S...      0.000013
# merch_zip_unique_count_for_merch_state_3                0.000000
# Merchant_dominance_score                                0.000000
# merch_zip_unique_count_for_merch_state_1                0.000000
# card_merch_unique_count_for_Cardnum_1                   0.000000
#
# [2650 rows x 1 columns]

# %%
vars_keep_sorted = pd.DataFrame(vars_keep_list)
vars_keep_sorted.columns=['variable']
vars_keep_sorted.set_index('variable',drop=True,inplace=True)
vars_keep_sorted.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Cardnum_unique_count_for_card_state_1, Card_Merchnum_desc_total_14, card_state_total_amount_1_by_60, Card_dow_unique_count_for_Card_Merchdesc_1, Cardnum_avg_3]

# %%
vars_keep_sorted = pd.concat([vars_keep_sorted,filter_score],axis=1,join='inner')

# %%
vars_keep_sorted.reset_index(inplace=True)
vars_keep_sorted.reset_index(inplace=True)
vars_keep_sorted['index'] = vars_keep_sorted['index'] + 1
vars_keep_sorted.rename(columns={'index':'wrapper order'},inplace=True)
vars_keep_sorted.to_csv('vars_keep_sorted.csv',index=False)
vars_keep_sorted
# Out:
#     wrapper order                                     variable  filter score
# 0               1        Cardnum_unique_count_for_card_state_1      0.518606
# 1               2                  Card_Merchnum_desc_total_14      0.265583
# 2               3              card_state_total_amount_1_by_60      0.348891
# 3               4   Card_dow_unique_count_for_Card_Merchdesc_1      0.486886
# 4               5                                Cardnum_avg_3      0.303772
# 5               6                       card_zip_count_1_by_60      0.339836
# 6               7                     Cardnum_count_0_by_30_sq      0.308604
# 7               8                             card_state_max_3      0.268834
# 8               9        Card_dow_unique_count_for_state_des_1      0.486873
# 9              10        Card_dow_unique_count_for_state_des_7      0.423220
# 10             11   Card_dow_unique_count_for_Card_Merchdesc_7      0.423220
# 11             12  Card_dow_unique_count_for_Card_Merchdesc_14      0.389733
# 12             13       Card_dow_unique_count_for_state_des_14      0.389733
# 13             14                    card_zip_count_1_by_60_sq      0.339836
# 14             15                                Cardnum_avg_0      0.338858
# 15             16                        Cardnum_count_0_by_30      0.308604
# 16             17                  card_state_count_1_by_30_sq      0.304836
# 17             18                     card_state_count_1_by_30      0.304836
# 18             19                               Card_dow_avg_7      0.303742
# 19             20                  Card_dow_variability_max_30      0.303203
# 20             21                              Card_dow_avg_14      0.293725
# 21             22                              Card_dow_avg_30      0.281136
# 22             23  Card_dow_unique_count_for_Card_Merchdesc_60      0.274776
# 23             24       Card_dow_unique_count_for_state_des_30      0.338943
# 24             25  Card_dow_unique_count_for_Card_Merchdesc_30      0.338943
# 25             26       Card_dow_unique_count_for_state_des_60      0.274726
# 26             27                             card_state_max_1      0.266484
# 27             28           Card_Merchnum_Zip_count_1_by_60_sq      0.303911
# 28             29              Card_Merchnum_Zip_count_1_by_60      0.303911
# 29             30                         Cardnum_vdratio_0by7      0.369439
# 30             31                               Card_dow_max_7      0.450698
# 31             32                card_zip_total_amount_1_by_60      0.345885
# 32             33                             Cardnum_total_60      0.287697
# 33             34                            Card_dow_count_30      0.375123
# 34             35                  Card_dow_variability_max_14      0.359189
# 35             36        Card_dow_unique_count_for_merch_zip_7      0.446890
# 36             37      Card_dow_unique_count_for_merch_state_7      0.446065
# 37             38                            Card_dow_total_30      0.426803
# 38             39     Card_dow_unique_count_for_merch_state_14      0.417871
# 39             40       Card_dow_unique_count_for_merch_zip_14      0.417733

# %%
vars_keep_list.append(index_name)
vars_keep_list.append(y_name)
vars_keep_list
# Out:
# ['Cardnum_unique_count_for_card_state_1',
#  'Card_Merchnum_desc_total_14',
#  'card_state_total_amount_1_by_60',
#  'Card_dow_unique_count_for_Card_Merchdesc_1',
#  'Cardnum_avg_3',
#  'card_zip_count_1_by_60',
#  'Cardnum_count_0_by_30_sq',
#  'card_state_max_3',
#  'Card_dow_unique_count_for_state_des_1',
#  'Card_dow_unique_count_for_state_des_7',
#  'Card_dow_unique_count_for_Card_Merchdesc_7',
#  'Card_dow_unique_count_for_Card_Merchdesc_14',
#  'Card_dow_unique_count_for_state_des_14',
#  'card_zip_count_1_by_60_sq',
#  'Cardnum_avg_0',
#  'Cardnum_count_0_by_30',
#  'card_state_count_1_by_30_sq',
#  'card_state_count_1_by_30',
#  'Card_dow_avg_7',
#  'Card_dow_variability_max_30',
#  'Card_dow_avg_14',
#  'Card_dow_avg_30',
#  'Card_dow_unique_count_for_Card_Merchdesc_60',
#  'Card_dow_unique_count_for_state_des_30',
#  'Card_dow_unique_count_for_Card_Merchdesc_30',
#  'Card_dow_unique_count_for_state_des_60',
#  'card_state_max_1',
#  'Card_Merchnum_Zip_count_1_by_60_sq',
#  'Card_Merchnum_Zip_count_1_by_60',
#  'Cardnum_vdratio_0by7',
#  'Card_dow_max_7',
#  'card_zip_total_amount_1_by_60',
#  'Cardnum_total_60',
#  'Card_dow_count_30',
#  'Card_dow_variability_max_14',
#  'Card_dow_unique_count_for_merch_zip_7',
#  'Card_dow_unique_count_for_merch_state_7',
#  'Card_dow_total_30',
#  'Card_dow_unique_count_for_merch_state_14',
#  'Card_dow_unique_count_for_merch_zip_14',
#  'Recnum',
#  'Fraud']

# %%
filter_score
# Out:
#                                                     filter score
# variable
# Cardnum_total_1                                         0.591114
# Cardnum_count_1                                         0.576927
# Cardnum_count_3                                         0.572199
# Cardnum_total_3                                         0.569585
# Cardnum_total_0                                         0.555080
# ...                                                          ...
# Card_Merchdesc_Zip_unique_count_for_Merchdesc_S...      0.000013
# merch_zip_unique_count_for_merch_state_3                0.000000
# Merchant_dominance_score                                0.000000
# merch_zip_unique_count_for_merch_state_1                0.000000
# card_merch_unique_count_for_Cardnum_1                   0.000000
#
# [2650 rows x 1 columns]

# %%
# %%time
df = pd.read_csv(file_name)
df.shape
# Out:
# CPU times: total: 36.8 s
# Wall time: 4h 39min 2s
# (98037, 2651)

# %%
df_keep = df.filter(vars_keep_list, axis=1)
print(df_keep.shape)
# Out:
# (98037, 42)

# %%
df_keep.to_csv('vars_final.csv',index=False)

# %%
print("duration: ", dt.datetime.now() - start_time)
# Out:
# duration:  9:06:52.585069

# %%
# %pwd
# Out:
# 'c:\\Users\\mrun7\\Downloads'
